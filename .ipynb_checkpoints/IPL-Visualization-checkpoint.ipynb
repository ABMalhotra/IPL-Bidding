# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from matplotlib.pyplot import figure
import numpy as np
from numpy.polynomial.polynomial import polyfit

# %%
df = pd.read_pickle('IPL_FinalData.pkl')
#data= sns.load_dataset('IPL_FinalData.pkl')
df2 = df.reset_index()
df2.columns
df3 = df2.groupby(['Team']).sum()
df3['ppg'] = df3['points']/df3['games']
df3['cost_per_point'] = df3['Spend_crores']/df3['points']
df3 = df3.drop(columns=['year'])
df3= df3.reset_index()
df3['color']=df3['Team'] #Temporary assignment will change
df3['TeamLong']=df3['Team']
# Out:
#                            Team  games  points       ppg  Spend_crores  \
# 0           Chennai Super Kings     72      94  1.305556    278.138869
# 1                Delhi Capitals    100      75  0.750000    390.148534
# 2                 Gujarat Lions     28      26  0.928571     99.150000
# 3               Kings XI Punjab    100      90  0.900000    339.505761
# 4         Kolkata Knight Riders    100     105  1.050000    376.896954
# 5                Mumbai Indians    100     116  1.160000    404.100392
# 6           Pune Warriors India     16       8  0.500000     55.094807
# 7              Rajasthan Royals     72      75  1.041667    231.865046
# 8        Rising Pune Supergiant     28      28  1.000000    114.500000
# 9   Royal Challengers Bangalore    100      90  0.900000    403.109716
# 10          Sunrisers Hyderabad    100     109  1.090000    348.989454
#
#     cost_per_point                        color                     TeamLong
# 0         2.958924          Chennai Super Kings          Chennai Super Kings
# 1         5.201980               Delhi Capitals               Delhi Capitals
# 2         3.813462                Gujarat Lions                Gujarat Lions
# 3         3.772286              Kings XI Punjab              Kings XI Punjab
# 4         3.589495        Kolkata Knight Riders        Kolkata Knight Riders
# 5         3.483624               Mumbai Indians               Mumbai Indians
# 6         6.886851          Pune Warriors India          Pune Warriors India
# 7         3.091534             Rajasthan Royals             Rajasthan Royals
# 8         4.089286       Rising Pune Supergiant       Rising Pune Supergiant
# 9         4.478997  Royal Challengers Bangalore  Royal Challengers Bangalore
# 10        3.201738          Sunrisers Hyderabad          Sunrisers Hyderabad

# %%
long_to_short_names = {}
team_to_colors = {}
for team in df3.Team:
    if team == 'Pune Warriors India':
        short_name = 'Pune-W'
        color = 'mistyrose'
    elif team == 'Delhi Capitals':
        short_name = 'Delhi'
        color = 'magenta'
    elif team == 'Royal Challengers Bangalore':
        short_name = 'RCB'
        color = 'red'
    elif team == 'Rising Pune Supergiant':
        short_name = 'Pune-S'
        color = 'khaki'
    elif team == 'Gujarat Lions':
        short_name = 'Guj'
        color = 'darkkhaki'
    elif team == 'Kings XI Punjab':
        short_name = 'KXIP'
        color = 'dimgray'
    elif team == 'Kolkata Knight Riders':
        short_name = 'KKR'
        color = 'black'
    elif team == 'Mumbai Indians':
        short_name = 'MI'
        color = 'blue'
    elif team == 'Sunrisers Hyderabad':
        short_name = 'SRH'
        color = 'orange'
    elif team == 'Rajasthan Royals':
        short_name = 'RR'
        color = 'hotpink'
    elif team == 'Chennai Super Kings':
        short_name = 'CSK'
        color = 'yellow'
        
    long_to_short_names[team] = short_name
    team_to_colors[team]= color    
    
df3 = df3.replace({'Team':long_to_short_names, 'color':team_to_colors})
df3 = df3.sort_values(['cost_per_point'],ascending=False)

# %%
#Result 1: Spending v/s Points
fig, ax = plt.subplots(figsize=(8, 6), dpi=200)
g = sns.scatterplot(x="points", y="Spend_crores", s=100, alpha=0.99,hue="TeamLong",
              data=df3, palette=team_to_colors,legend='brief')
ax.legend().set_title('')
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])


plt.ylabel("Total Money Spent (in Crore Rs)")
plt.xlabel("Total points since 2013")
plt.title("Does money get you more points?") 
b, m = polyfit(df3.points, df3.Spend_crores, 1)
plt.plot(df3.points, b + m * df3.points, '-',linewidth=0.5)

# %%
#Result 2: Spending v/s Points
figure(num=None, figsize=(8, 6), dpi=200, facecolor='w', edgecolor='k')
sns.scatterplot(x="Team", y="cost_per_point", s=df3.points*df3.points/10, alpha=0.99,hue="TeamLong",
              data=df3, palette=team_to_colors,legend=False)
plt.ylabel("Cost per point (in Crore Rs)")
plt.xlabel("Team Name")
plt.title("Which teams are spending efficent?") 
plt.text(5, 5, 'Size of circle ~ Total points')
plt.show()

# %%
#Result 3: Money being spent in IPL auctions
